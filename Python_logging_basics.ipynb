# %% [markdown]
# <a href="https://colab.research.google.com/github/tannu64/Energy-Audit/blob/main/Python_logging_basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Logging in Python is a built-in module that provides a flexible framework for emitting log messages from Python programs. It is highly configurable and is used to track events in an application for debugging or operational purposes.
#
# Why Use Logging?
#
# Debugging: Helps identify and resolve issues.
# Monitoring: Tracks application behavior and performance.
# Error Reporting: Records errors for later review.

# %%
import logging

# Configure the logging system
logging.basicConfig(level=logging.DEBUG, format='%(asctime)s - %(levelname)s - %(message)s')

# Log messages
logging.debug('This is a debug message')
logging.info('This is an info message')
logging.warning('This is a warning message')
logging.error('This is an error message')
logging.critical('This is a critical message')
# Out:
# WARNING:root:This is a warning message
# ERROR:root:This is an error message
# CRITICAL:root:This is a critical message

# %% [markdown]
# # **Advanced Logging Configuration**
#
# You can configure logging with more customization using a dictionary or file configuration.

# %%
logging.basicConfig(
    filename='app.log',
    level=logging.INFO,
    format='%(asctime)s - %(name)s - %(levelname)s - %(message)s'
)

logging.info('This message will be written to the file')

# %% [markdown]
# # **Using Handlers and Formatters**
#
# Handlers direct log messages to specific destinations (console, file, etc.), while formatters control the output format.

# %%
# Custom logger
logger = logging.getLogger('my_logger')
logger.setLevel(logging.DEBUG)

# Create a file handler
file_handler = logging.FileHandler('file.log')
file_handler.setLevel(logging.ERROR)

# Create a console handler
console_handler = logging.StreamHandler()
console_handler.setLevel(logging.DEBUG)

# Create a formatter and set it for handlers
formatter = logging.Formatter('%(asctime)s - %(name)s - %(levelname)s - %(message)s')
file_handler.setFormatter(formatter)
console_handler.setFormatter(formatter)

# Add handlers to the logger
logger.addHandler(file_handler)
logger.addHandler(console_handler)

# Log messages
logger.debug('This is a debug message')
logger.error('This is an error message')
# Out:
# 2024-12-24 19:16:08,487 - my_logger - DEBUG - This is a debug message
# DEBUG:my_logger:This is a debug message
# 2024-12-24 19:16:08,494 - my_logger - ERROR - This is an error message
# ERROR:my_logger:This is an error message

# %%
# Custom logger
logger = logging.getLogger('my_logger')
logger.setLevel(logging.DEBUG)

# Create a file handler
file_handler = logging.FileHandler('file.log')
file_handler.setLevel(logging.ERROR)

# Create a console handler
console_handler = logging.StreamHandler()
console_handler.setLevel(logging.DEBUG)

# Create a formatter and set it for handlers
formatter = logging.Formatter('%(asctime)s - %(name)s - %(levelname)s - %(message)s')
file_handler.setFormatter(formatter)
console_handler.setFormatter(formatter)

# Add handlers to the logger
logger.addHandler(file_handler)
logger.addHandler(console_handler)

# Log messages
logger.debug('This is a debug message')
logger.error('This is an error message')
# Out:
# 2024-12-24 19:18:18,808 - my_logger - DEBUG - This is a debug message
# 2024-12-24 19:18:18,808 - my_logger - DEBUG - This is a debug message
# DEBUG:my_logger:This is a debug message
# 2024-12-24 19:18:18,814 - my_logger - ERROR - This is an error message
# 2024-12-24 19:18:18,814 - my_logger - ERROR - This is an error message
# ERROR:my_logger:This is an error message

# %%
from logging.handlers import RotatingFileHandler

# Create a rotating file handler
handler = RotatingFileHandler('app.log', maxBytes=2000, backupCount=5)
logger = logging.getLogger('rotating_logger')
logger.addHandler(handler)

logger.error('This is a log message')
# Out:
# ERROR:rotating_logger:This is a log message

# %%
import logging

# Configure the logging system
logging.basicConfig(
    level=logging.DEBUG,
    format='%(asctime)s - %(levelname)s - %(message)s',
    handlers=[
        logging.FileHandler("application.log"),  # Log to file
        logging.StreamHandler()                 # Log to console
    ]
)

# Log at different levels
logging.debug("This is a debug message")
logging.info("This is an info message")
logging.warning("This is a warning message")
logging.error("This is an error message")
logging.critical("This is a critical message")
# Out:
# WARNING:root:This is a warning message
# ERROR:root:This is an error message
# CRITICAL:root:This is a critical message

# %%
import logging

# Create loggers
app_logger = logging.getLogger('app_logger')
db_logger = logging.getLogger('db_logger')

# Set level and handlers for app_logger
app_logger.setLevel(logging.DEBUG)
app_handler = logging.FileHandler('app.log')
app_formatter = logging.Formatter('%(asctime)s - %(name)s - %(levelname)s - %(message)s')
app_handler.setFormatter(app_formatter)
app_logger.addHandler(app_handler)

# Set level and handlers for db_logger
db_logger.setLevel(logging.ERROR)
db_handler = logging.FileHandler('db.log')
db_formatter = logging.Formatter('%(asctime)s - %(name)s - %(levelname)s - %(message)s')
db_handler.setFormatter(db_formatter)
db_logger.addHandler(db_handler)

# Log messages
app_logger.info("Application started")
db_logger.error("Database connection failed")
app_logger.debug("Debugging application flow")
# Out:
# INFO:app_logger:Application started
# ERROR:db_logger:Database connection failed
# DEBUG:app_logger:Debugging application flow

# %%
import logging

# Set up main logger
main_logger = logging.getLogger('ecommerce')
main_logger.setLevel(logging.DEBUG)

# File handlers
user_activity_handler = logging.FileHandler('user_activity.log')
payment_handler = logging.FileHandler('payment.log')
error_handler = logging.FileHandler('error.log')

# Formatters
formatter = logging.Formatter('%(asctime)s - %(name)s - %(levelname)s - %(message)s')
user_activity_handler.setFormatter(formatter)
payment_handler.setFormatter(formatter)
error_handler.setFormatter(formatter)

# Set levels
user_activity_handler.setLevel(logging.INFO)
payment_handler.setLevel(logging.WARNING)
error_handler.setLevel(logging.ERROR)

# Add handlers to the logger
main_logger.addHandler(user_activity_handler)
main_logger.addHandler(payment_handler)
main_logger.addHandler(error_handler)

# Log events
main_logger.info("User logged in")
main_logger.warning("Payment gateway response delayed")
main_logger.error("Server crashed during order placement")
# Out:
# INFO:ecommerce:User logged in
# WARNING:ecommerce:Payment gateway response delayed
# ERROR:ecommerce:Server crashed during order placement

# %%
import logging

# User logger
user_logger = logging.getLogger('user_logger')
user_handler = logging.FileHandler('user.log')
user_formatter = logging.Formatter('%(asctime)s - %(name)s - %(levelname)s - %(message)s')
user_handler.setFormatter(user_formatter)
user_logger.addHandler(user_handler)
user_logger.setLevel(logging.INFO)

# Message logger
message_logger = logging.getLogger('message_logger')
message_handler = logging.FileHandler('message.log')
message_formatter = logging.Formatter('%(asctime)s - %(name)s - %(levelname)s - %(message)s')
message_handler.setFormatter(message_formatter)
message_logger.addHandler(message_handler)
message_logger.setLevel(logging.DEBUG)

# Log events
user_logger.info("User logged in: JohnDoe")
message_logger.debug("Message sent: Hello!")
message_logger.debug("Message received: Hi, John!")
user_logger.info("User logged out: JohnDoe")
# Out:
# INFO:user_logger:User logged in: JohnDoe
# DEBUG:message_logger:Message sent: Hello!
# DEBUG:message_logger:Message received: Hi, John!
# INFO:user_logger:User logged out: JohnDoe

# %%
import logging
from logging.handlers import RotatingFileHandler

# Rotating file handler
handler = RotatingFileHandler('app.log', maxBytes=1024 * 1024, backupCount=3)
logger = logging.getLogger('rotating_logger')
logger.setLevel(logging.DEBUG)
logger.addHandler(handler)

# Generate log messages
for i in range(1000):
    logger.debug(f"Log message {i}")
# Out:
# DEBUG:rotating_logger:Log message 0
# DEBUG:rotating_logger:Log message 1
# DEBUG:rotating_logger:Log message 2
# DEBUG:rotating_logger:Log message 3
# DEBUG:rotating_logger:Log message 4
# DEBUG:rotating_logger:Log message 5
# DEBUG:rotating_logger:Log message 6
# DEBUG:rotating_logger:Log message 7
# DEBUG:rotating_logger:Log message 8
# DEBUG:rotating_logger:Log message 9
# DEBUG:rotating_logger:Log message 10
# DEBUG:rotating_logger:Log message 11
# DEBUG:rotating_logger:Log message 12
# DEBUG:rotating_logger:Log message 13
# DEBUG:rotating_logger:Log message 14
# DEBUG:rotating_logger:Log message 15
# DEBUG:rotating_logger:Log message 16
# DEBUG:rotating_logger:Log message 17
# DEBUG:rotating_logger:Log message 18
# DEBUG:rotating_logger:Log message 19
# DEBUG:rotating_logger:Log message 20
# DEBUG:rotating_logger:Log message 21
# DEBUG:rotating_logger:Log message 22
# DEBUG:rotating_logger:Log message 23
# DEBUG:rotating_logger:Log message 24
# DEBUG:rotating_logger:Log message 25
# DEBUG:rotating_logger:Log message 26
# DEBUG:rotating_logger:Log message 27
# DEBUG:rotating_logger:Log message 28
# DEBUG:rotating_logger:Log message 29
# DEBUG:rotating_logger:Log message 30
# DEBUG:rotating_logger:Log message 31
# DEBUG:rotating_logger:Log message 32
# DEBUG:rotating_logger:Log message 33
# DEBUG:rotating_logger:Log message 34
# DEBUG:rotating_logger:Log message 35
# DEBUG:rotating_logger:Log message 36
# DEBUG:rotating_logger:Log message 37
# DEBUG:rotating_logger:Log message 38
# DEBUG:rotating_logger:Log message 39
# DEBUG:rotating_logger:Log message 40
# DEBUG:rotating_logger:Log message 41
# DEBUG:rotating_logger:Log message 42
# DEBUG:rotating_logger:Log message 43
# DEBUG:rotating_logger:Log message 44
# DEBUG:rotating_logger:Log message 45
# DEBUG:rotating_logger:Log message 46
# DEBUG:rotating_logger:Log message 47
# DEBUG:rotating_logger:Log message 48
# DEBUG:rotating_logger:Log message 49
# DEBUG:rotating_logger:Log message 50
# DEBUG:rotating_logger:Log message 51
# DEBUG:rotating_logger:Log message 52
# DEBUG:rotating_logger:Log message 53
# DEBUG:rotating_logger:Log message 54
# DEBUG:rotating_logger:Log message 55
# DEBUG:rotating_logger:Log message 56
# DEBUG:rotating_logger:Log message 57
# DEBUG:rotating_logger:Log message 58
# DEBUG:rotating_logger:Log message 59
# DEBUG:rotating_logger:Log message 60
# DEBUG:rotating_logger:Log message 61
# DEBUG:rotating_logger:Log message 62
# DEBUG:rotating_logger:Log message 63
# DEBUG:rotating_logger:Log message 64
# DEBUG:rotating_logger:Log message 65
# DEBUG:rotating_logger:Log message 66
# DEBUG:rotating_logger:Log message 67
# DEBUG:rotating_logger:Log message 68
# DEBUG:rotating_logger:Log message 69
# DEBUG:rotating_logger:Log message 70
# DEBUG:rotating_logger:Log message 71
# DEBUG:rotating_logger:Log message 72
# DEBUG:rotating_logger:Log message 73
# DEBUG:rotating_logger:Log message 74
# DEBUG:rotating_logger:Log message 75
# DEBUG:rotating_logger:Log message 76
# DEBUG:rotating_logger:Log message 77
# DEBUG:rotating_logger:Log message 78
# DEBUG:rotating_logger:Log message 79
# DEBUG:rotating_logger:Log message 80
# DEBUG:rotating_logger:Log message 81
# DEBUG:rotating_logger:Log message 82
# DEBUG:rotating_logger:Log message 83
# DEBUG:rotating_logger:Log message 84
# DEBUG:rotating_logger:Log message 85
# DEBUG:rotating_logger:Log message 86
# DEBUG:rotating_logger:Log message 87
# DEBUG:rotating_logger:Log message 88
# DEBUG:rotating_logger:Log message 89
# DEBUG:rotating_logger:Log message 90
# DEBUG:rotating_logger:Log message 91
# DEBUG:rotating_logger:Log message 92
# DEBUG:rotating_logger:Log message 93
# DEBUG:rotating_logger:Log message 94
# DEBUG:rotating_logger:Log message 95
# DEBUG:rotating_logger:Log message 96
# DEBUG:rotating_logger:Log message 97
# DEBUG:rotating_logger:Log message 98
# DEBUG:rotating_logger:Log message 99
# DEBUG:rotating_logger:Log message 100
# DEBUG:rotating_logger:Log message 101
# DEBUG:rotating_logger:Log message 102
# DEBUG:rotating_logger:Log message 103
# DEBUG:rotating_logger:Log message 104
# DEBUG:rotating_logger:Log message 105
# DEBUG:rotating_logger:Log message 106
# DEBUG:rotating_logger:Log message 107
# DEBUG:rotating_logger:Log message 108
# DEBUG:rotating_logger:Log message 109
# DEBUG:rotating_logger:Log message 110
# DEBUG:rotating_logger:Log message 111
# DEBUG:rotating_logger:Log message 112
# DEBUG:rotating_logger:Log message 113
# DEBUG:rotating_logger:Log message 114
# DEBUG:rotating_logger:Log message 115
# DEBUG:rotating_logger:Log message 116
# DEBUG:rotating_logger:Log message 117
# DEBUG:rotating_logger:Log message 118
# DEBUG:rotating_logger:Log message 119
# DEBUG:rotating_logger:Log message 120
# DEBUG:rotating_logger:Log message 121
# DEBUG:rotating_logger:Log message 122
# DEBUG:rotating_logger:Log message 123
# DEBUG:rotating_logger:Log message 124
# DEBUG:rotating_logger:Log message 125
# DEBUG:rotating_logger:Log message 126
# DEBUG:rotating_logger:Log message 127
# DEBUG:rotating_logger:Log message 128
# DEBUG:rotating_logger:Log message 129
# DEBUG:rotating_logger:Log message 130
# DEBUG:rotating_logger:Log message 131
# DEBUG:rotating_logger:Log message 132
# DEBUG:rotating_logger:Log message 133
# DEBUG:rotating_logger:Log message 134
# DEBUG:rotating_logger:Log message 135
# DEBUG:rotating_logger:Log message 136
# DEBUG:rotating_logger:Log message 137
# DEBUG:rotating_logger:Log message 138
# DEBUG:rotating_logger:Log message 139
# DEBUG:rotating_logger:Log message 140
# DEBUG:rotating_logger:Log message 141
# DEBUG:rotating_logger:Log message 142
# DEBUG:rotating_logger:Log message 143
# DEBUG:rotating_logger:Log message 144
# DEBUG:rotating_logger:Log message 145
# DEBUG:rotating_logger:Log message 146
# DEBUG:rotating_logger:Log message 147
# DEBUG:rotating_logger:Log message 148
# DEBUG:rotating_logger:Log message 149
# DEBUG:rotating_logger:Log message 150
# DEBUG:rotating_logger:Log message 151
# DEBUG:rotating_logger:Log message 152
# DEBUG:rotating_logger:Log message 153
# DEBUG:rotating_logger:Log message 154
# DEBUG:rotating_logger:Log message 155
# DEBUG:rotating_logger:Log message 156
# DEBUG:rotating_logger:Log message 157
# DEBUG:rotating_logger:Log message 158
# DEBUG:rotating_logger:Log message 159
# DEBUG:rotating_logger:Log message 160
# DEBUG:rotating_logger:Log message 161
# DEBUG:rotating_logger:Log message 162
# DEBUG:rotating_logger:Log message 163
# DEBUG:rotating_logger:Log message 164
# DEBUG:rotating_logger:Log message 165
# DEBUG:rotating_logger:Log message 166
# DEBUG:rotating_logger:Log message 167
# DEBUG:rotating_logger:Log message 168
# DEBUG:rotating_logger:Log message 169
# DEBUG:rotating_logger:Log message 170
# DEBUG:rotating_logger:Log message 171
# DEBUG:rotating_logger:Log message 172
# DEBUG:rotating_logger:Log message 173
# DEBUG:rotating_logger:Log message 174
# DEBUG:rotating_logger:Log message 175
# DEBUG:rotating_logger:Log message 176
# DEBUG:rotating_logger:Log message 177
# DEBUG:rotating_logger:Log message 178
# DEBUG:rotating_logger:Log message 179
# DEBUG:rotating_logger:Log message 180
# DEBUG:rotating_logger:Log message 181
# DEBUG:rotating_logger:Log message 182
# DEBUG:rotating_logger:Log message 183
# DEBUG:rotating_logger:Log message 184
# DEBUG:rotating_logger:Log message 185
# DEBUG:rotating_logger:Log message 186
# DEBUG:rotating_logger:Log message 187
# DEBUG:rotating_logger:Log message 188
# DEBUG:rotating_logger:Log message 189
# DEBUG:rotating_logger:Log message 190
# DEBUG:rotating_logger:Log message 191
# DEBUG:rotating_logger:Log message 192
# DEBUG:rotating_logger:Log message 193
# DEBUG:rotating_logger:Log message 194
# DEBUG:rotating_logger:Log message 195
# DEBUG:rotating_logger:Log message 196
# DEBUG:rotating_logger:Log message 197
# DEBUG:rotating_logger:Log message 198
# DEBUG:rotating_logger:Log message 199
# DEBUG:rotating_logger:Log message 200
# DEBUG:rotating_logger:Log message 201
# DEBUG:rotating_logger:Log message 202
# DEBUG:rotating_logger:Log message 203
# DEBUG:rotating_logger:Log message 204
# DEBUG:rotating_logger:Log message 205
# DEBUG:rotating_logger:Log message 206
# DEBUG:rotating_logger:Log message 207
# DEBUG:rotating_logger:Log message 208
# DEBUG:rotating_logger:Log message 209
# DEBUG:rotating_logger:Log message 210
# DEBUG:rotating_logger:Log message 211
# DEBUG:rotating_logger:Log message 212
# DEBUG:rotating_logger:Log message 213
# DEBUG:rotating_logger:Log message 214
# DEBUG:rotating_logger:Log message 215
# DEBUG:rotating_logger:Log message 216
# DEBUG:rotating_logger:Log message 217
# DEBUG:rotating_logger:Log message 218
# DEBUG:rotating_logger:Log message 219
# DEBUG:rotating_logger:Log message 220
# DEBUG:rotating_logger:Log message 221
# DEBUG:rotating_logger:Log message 222
# DEBUG:rotating_logger:Log message 223
# DEBUG:rotating_logger:Log message 224
# DEBUG:rotating_logger:Log message 225
# DEBUG:rotating_logger:Log message 226
# DEBUG:rotating_logger:Log message 227
# DEBUG:rotating_logger:Log message 228
# DEBUG:rotating_logger:Log message 229
# DEBUG:rotating_logger:Log message 230
# DEBUG:rotating_logger:Log message 231
# DEBUG:rotating_logger:Log message 232
# DEBUG:rotating_logger:Log message 233
# DEBUG:rotating_logger:Log message 234
# DEBUG:rotating_logger:Log message 235
# DEBUG:rotating_logger:Log message 236
# DEBUG:rotating_logger:Log message 237
# DEBUG:rotating_logger:Log message 238
# DEBUG:rotating_logger:Log message 239
# DEBUG:rotating_logger:Log message 240
# DEBUG:rotating_logger:Log message 241
# DEBUG:rotating_logger:Log message 242
# DEBUG:rotating_logger:Log message 243
# DEBUG:rotating_logger:Log message 244
# DEBUG:rotating_logger:Log message 245
# DEBUG:rotating_logger:Log message 246
# DEBUG:rotating_logger:Log message 247
# DEBUG:rotating_logger:Log message 248
# DEBUG:rotating_logger:Log message 249
# DEBUG:rotating_logger:Log message 250
# DEBUG:rotating_logger:Log message 251
# DEBUG:rotating_logger:Log message 252
# DEBUG:rotating_logger:Log message 253
# DEBUG:rotating_logger:Log message 254
# DEBUG:rotating_logger:Log message 255
# DEBUG:rotating_logger:Log message 256
# DEBUG:rotating_logger:Log message 257
# DEBUG:rotating_logger:Log message 258
# DEBUG:rotating_logger:Log message 259
# DEBUG:rotating_logger:Log message 260
# DEBUG:rotating_logger:Log message 261
# DEBUG:rotating_logger:Log message 262
# DEBUG:rotating_logger:Log message 263
# DEBUG:rotating_logger:Log message 264
# DEBUG:rotating_logger:Log message 265
# DEBUG:rotating_logger:Log message 266
# DEBUG:rotating_logger:Log message 267
# DEBUG:rotating_logger:Log message 268
# DEBUG:rotating_logger:Log message 269
# DEBUG:rotating_logger:Log message 270
# DEBUG:rotating_logger:Log message 271
# DEBUG:rotating_logger:Log message 272
# DEBUG:rotating_logger:Log message 273
# DEBUG:rotating_logger:Log message 274
# DEBUG:rotating_logger:Log message 275
# DEBUG:rotating_logger:Log message 276
# DEBUG:rotating_logger:Log message 277
# DEBUG:rotating_logger:Log message 278
# DEBUG:rotating_logger:Log message 279
# DEBUG:rotating_logger:Log message 280
# DEBUG:rotating_logger:Log message 281
# DEBUG:rotating_logger:Log message 282
# DEBUG:rotating_logger:Log message 283
# DEBUG:rotating_logger:Log message 284
# DEBUG:rotating_logger:Log message 285
# DEBUG:rotating_logger:Log message 286
# DEBUG:rotating_logger:Log message 287
# DEBUG:rotating_logger:Log message 288
# DEBUG:rotating_logger:Log message 289
# DEBUG:rotating_logger:Log message 290
# DEBUG:rotating_logger:Log message 291
# DEBUG:rotating_logger:Log message 292
# DEBUG:rotating_logger:Log message 293
# DEBUG:rotating_logger:Log message 294
# DEBUG:rotating_logger:Log message 295
# DEBUG:rotating_logger:Log message 296
# DEBUG:rotating_logger:Log message 297
# DEBUG:rotating_logger:Log message 298
# DEBUG:rotating_logger:Log message 299
# DEBUG:rotating_logger:Log message 300
# DEBUG:rotating_logger:Log message 301
# DEBUG:rotating_logger:Log message 302
# DEBUG:rotating_logger:Log message 303
# DEBUG:rotating_logger:Log message 304
# DEBUG:rotating_logger:Log message 305
# DEBUG:rotating_logger:Log message 306
# DEBUG:rotating_logger:Log message 307
# DEBUG:rotating_logger:Log message 308
# DEBUG:rotating_logger:Log message 309
# DEBUG:rotating_logger:Log message 310
# DEBUG:rotating_logger:Log message 311
# DEBUG:rotating_logger:Log message 312
# DEBUG:rotating_logger:Log message 313
# DEBUG:rotating_logger:Log message 314
# DEBUG:rotating_logger:Log message 315
# DEBUG:rotating_logger:Log message 316
# DEBUG:rotating_logger:Log message 317
# DEBUG:rotating_logger:Log message 318
# DEBUG:rotating_logger:Log message 319
# DEBUG:rotating_logger:Log message 320
# DEBUG:rotating_logger:Log message 321
# DEBUG:rotating_logger:Log message 322
# DEBUG:rotating_logger:Log message 323
# DEBUG:rotating_logger:Log message 324
# DEBUG:rotating_logger:Log message 325
# DEBUG:rotating_logger:Log message 326
# DEBUG:rotating_logger:Log message 327
# DEBUG:rotating_logger:Log message 328
# DEBUG:rotating_logger:Log message 329
# DEBUG:rotating_logger:Log message 330
# DEBUG:rotating_logger:Log message 331
# DEBUG:rotating_logger:Log message 332
# DEBUG:rotating_logger:Log message 333
# DEBUG:rotating_logger:Log message 334
# DEBUG:rotating_logger:Log message 335
# DEBUG:rotating_logger:Log message 336
# DEBUG:rotating_logger:Log message 337
# DEBUG:rotating_logger:Log message 338
# DEBUG:rotating_logger:Log message 339
# DEBUG:rotating_logger:Log message 340
# DEBUG:rotating_logger:Log message 341
# DEBUG:rotating_logger:Log message 342
# DEBUG:rotating_logger:Log message 343
# DEBUG:rotating_logger:Log message 344
# DEBUG:rotating_logger:Log message 345
# DEBUG:rotating_logger:Log message 346
# DEBUG:rotating_logger:Log message 347
# DEBUG:rotating_logger:Log message 348
# DEBUG:rotating_logger:Log message 349
# DEBUG:rotating_logger:Log message 350
# DEBUG:rotating_logger:Log message 351
# DEBUG:rotating_logger:Log message 352
# DEBUG:rotating_logger:Log message 353
# DEBUG:rotating_logger:Log message 354
# DEBUG:rotating_logger:Log message 355
# DEBUG:rotating_logger:Log message 356
# DEBUG:rotating_logger:Log message 357
# DEBUG:rotating_logger:Log message 358
# DEBUG:rotating_logger:Log message 359
# DEBUG:rotating_logger:Log message 360
# DEBUG:rotating_logger:Log message 361
# DEBUG:rotating_logger:Log message 362
# DEBUG:rotating_logger:Log message 363
# DEBUG:rotating_logger:Log message 364
# DEBUG:rotating_logger:Log message 365
# DEBUG:rotating_logger:Log message 366
# DEBUG:rotating_logger:Log message 367
# DEBUG:rotating_logger:Log message 368
# DEBUG:rotating_logger:Log message 369
# DEBUG:rotating_logger:Log message 370
# DEBUG:rotating_logger:Log message 371
# DEBUG:rotating_logger:Log message 372
# DEBUG:rotating_logger:Log message 373
# DEBUG:rotating_logger:Log message 374
# DEBUG:rotating_logger:Log message 375
# DEBUG:rotating_logger:Log message 376
# DEBUG:rotating_logger:Log message 377
# DEBUG:rotating_logger:Log message 378
# DEBUG:rotating_logger:Log message 379
# DEBUG:rotating_logger:Log message 380
# DEBUG:rotating_logger:Log message 381
# DEBUG:rotating_logger:Log message 382
# DEBUG:rotating_logger:Log message 383
# DEBUG:rotating_logger:Log message 384
# DEBUG:rotating_logger:Log message 385
# DEBUG:rotating_logger:Log message 386
# DEBUG:rotating_logger:Log message 387
# DEBUG:rotating_logger:Log message 388
# DEBUG:rotating_logger:Log message 389
# DEBUG:rotating_logger:Log message 390
# DEBUG:rotating_logger:Log message 391
# DEBUG:rotating_logger:Log message 392
# DEBUG:rotating_logger:Log message 393
# DEBUG:rotating_logger:Log message 394
# DEBUG:rotating_logger:Log message 395
# DEBUG:rotating_logger:Log message 396
# DEBUG:rotating_logger:Log message 397
# DEBUG:rotating_logger:Log message 398
# DEBUG:rotating_logger:Log message 399
# DEBUG:rotating_logger:Log message 400
# DEBUG:rotating_logger:Log message 401
# DEBUG:rotating_logger:Log message 402
# DEBUG:rotating_logger:Log message 403
# DEBUG:rotating_logger:Log message 404
# DEBUG:rotating_logger:Log message 405
# DEBUG:rotating_logger:Log message 406
# DEBUG:rotating_logger:Log message 407
# DEBUG:rotating_logger:Log message 408
# DEBUG:rotating_logger:Log message 409
# DEBUG:rotating_logger:Log message 410
# DEBUG:rotating_logger:Log message 411
# DEBUG:rotating_logger:Log message 412
# DEBUG:rotating_logger:Log message 413
# DEBUG:rotating_logger:Log message 414
# DEBUG:rotating_logger:Log message 415
# DEBUG:rotating_logger:Log message 416
# DEBUG:rotating_logger:Log message 417
# DEBUG:rotating_logger:Log message 418
# DEBUG:rotating_logger:Log message 419
# DEBUG:rotating_logger:Log message 420
# DEBUG:rotating_logger:Log message 421
# DEBUG:rotating_logger:Log message 422
# DEBUG:rotating_logger:Log message 423
# DEBUG:rotating_logger:Log message 424
# DEBUG:rotating_logger:Log message 425
# DEBUG:rotating_logger:Log message 426
# DEBUG:rotating_logger:Log message 427
# DEBUG:rotating_logger:Log message 428
# DEBUG:rotating_logger:Log message 429
# DEBUG:rotating_logger:Log message 430
# DEBUG:rotating_logger:Log message 431
# DEBUG:rotating_logger:Log message 432
# DEBUG:rotating_logger:Log message 433
# DEBUG:rotating_logger:Log message 434
# DEBUG:rotating_logger:Log message 435
# DEBUG:rotating_logger:Log message 436
# DEBUG:rotating_logger:Log message 437
# DEBUG:rotating_logger:Log message 438
# DEBUG:rotating_logger:Log message 439
# DEBUG:rotating_logger:Log message 440
# DEBUG:rotating_logger:Log message 441
# DEBUG:rotating_logger:Log message 442
# DEBUG:rotating_logger:Log message 443
# DEBUG:rotating_logger:Log message 444
# DEBUG:rotating_logger:Log message 445
# DEBUG:rotating_logger:Log message 446
# DEBUG:rotating_logger:Log message 447
# DEBUG:rotating_logger:Log message 448
# DEBUG:rotating_logger:Log message 449
# DEBUG:rotating_logger:Log message 450
# DEBUG:rotating_logger:Log message 451
# DEBUG:rotating_logger:Log message 452
# DEBUG:rotating_logger:Log message 453
# DEBUG:rotating_logger:Log message 454
# DEBUG:rotating_logger:Log message 455
# DEBUG:rotating_logger:Log message 456
# DEBUG:rotating_logger:Log message 457
# DEBUG:rotating_logger:Log message 458
# DEBUG:rotating_logger:Log message 459
# DEBUG:rotating_logger:Log message 460
# DEBUG:rotating_logger:Log message 461
# DEBUG:rotating_logger:Log message 462
# DEBUG:rotating_logger:Log message 463
# DEBUG:rotating_logger:Log message 464
# DEBUG:rotating_logger:Log message 465
# DEBUG:rotating_logger:Log message 466
# DEBUG:rotating_logger:Log message 467
# DEBUG:rotating_logger:Log message 468
# DEBUG:rotating_logger:Log message 469
# DEBUG:rotating_logger:Log message 470
# DEBUG:rotating_logger:Log message 471
# DEBUG:rotating_logger:Log message 472
# DEBUG:rotating_logger:Log message 473
# DEBUG:rotating_logger:Log message 474
# DEBUG:rotating_logger:Log message 475
# DEBUG:rotating_logger:Log message 476
# DEBUG:rotating_logger:Log message 477
# DEBUG:rotating_logger:Log message 478
# DEBUG:rotating_logger:Log message 479
# DEBUG:rotating_logger:Log message 480
# DEBUG:rotating_logger:Log message 481
# DEBUG:rotating_logger:Log message 482
# DEBUG:rotating_logger:Log message 483
# DEBUG:rotating_logger:Log message 484
# DEBUG:rotating_logger:Log message 485
# DEBUG:rotating_logger:Log message 486
# DEBUG:rotating_logger:Log message 487
# DEBUG:rotating_logger:Log message 488
# DEBUG:rotating_logger:Log message 489
# DEBUG:rotating_logger:Log message 490
# DEBUG:rotating_logger:Log message 491
# DEBUG:rotating_logger:Log message 492
# DEBUG:rotating_logger:Log message 493
# DEBUG:rotating_logger:Log message 494
# DEBUG:rotating_logger:Log message 495
# DEBUG:rotating_logger:Log message 496
# DEBUG:rotating_logger:Log message 497
# DEBUG:rotating_logger:Log message 498
# DEBUG:rotating_logger:Log message 499
# DEBUG:rotating_logger:Log message 500
# DEBUG:rotating_logger:Log message 501
# DEBUG:rotating_logger:Log message 502
# DEBUG:rotating_logger:Log message 503
# DEBUG:rotating_logger:Log message 504
# DEBUG:rotating_logger:Log message 505
# DEBUG:rotating_logger:Log message 506
# DEBUG:rotating_logger:Log message 507
# DEBUG:rotating_logger:Log message 508
# DEBUG:rotating_logger:Log message 509
# DEBUG:rotating_logger:Log message 510
# DEBUG:rotating_logger:Log message 511
# DEBUG:rotating_logger:Log message 512
# DEBUG:rotating_logger:Log message 513
# DEBUG:rotating_logger:Log message 514
# DEBUG:rotating_logger:Log message 515
# DEBUG:rotating_logger:Log message 516
# DEBUG:rotating_logger:Log message 517
# DEBUG:rotating_logger:Log message 518
# DEBUG:rotating_logger:Log message 519
# DEBUG:rotating_logger:Log message 520
# DEBUG:rotating_logger:Log message 521
# DEBUG:rotating_logger:Log message 522
# DEBUG:rotating_logger:Log message 523
# DEBUG:rotating_logger:Log message 524
# DEBUG:rotating_logger:Log message 525
# DEBUG:rotating_logger:Log message 526
# DEBUG:rotating_logger:Log message 527
# DEBUG:rotating_logger:Log message 528
# DEBUG:rotating_logger:Log message 529
# DEBUG:rotating_logger:Log message 530
# DEBUG:rotating_logger:Log message 531
# DEBUG:rotating_logger:Log message 532
# DEBUG:rotating_logger:Log message 533
# DEBUG:rotating_logger:Log message 534
# DEBUG:rotating_logger:Log message 535
# DEBUG:rotating_logger:Log message 536
# DEBUG:rotating_logger:Log message 537
# DEBUG:rotating_logger:Log message 538
# DEBUG:rotating_logger:Log message 539
# DEBUG:rotating_logger:Log message 540
# DEBUG:rotating_logger:Log message 541
# DEBUG:rotating_logger:Log message 542
# DEBUG:rotating_logger:Log message 543
# DEBUG:rotating_logger:Log message 544
# DEBUG:rotating_logger:Log message 545
# DEBUG:rotating_logger:Log message 546
# DEBUG:rotating_logger:Log message 547
# DEBUG:rotating_logger:Log message 548
# DEBUG:rotating_logger:Log message 549
# DEBUG:rotating_logger:Log message 550
# DEBUG:rotating_logger:Log message 551
# DEBUG:rotating_logger:Log message 552
# DEBUG:rotating_logger:Log message 553
# DEBUG:rotating_logger:Log message 554
# DEBUG:rotating_logger:Log message 555
# DEBUG:rotating_logger:Log message 556
# DEBUG:rotating_logger:Log message 557
# DEBUG:rotating_logger:Log message 558
# DEBUG:rotating_logger:Log message 559
# DEBUG:rotating_logger:Log message 560
# DEBUG:rotating_logger:Log message 561
# DEBUG:rotating_logger:Log message 562
# DEBUG:rotating_logger:Log message 563
# DEBUG:rotating_logger:Log message 564
# DEBUG:rotating_logger:Log message 565
# DEBUG:rotating_logger:Log message 566
# DEBUG:rotating_logger:Log message 567
# DEBUG:rotating_logger:Log message 568
# DEBUG:rotating_logger:Log message 569
# DEBUG:rotating_logger:Log message 570
# DEBUG:rotating_logger:Log message 571
# DEBUG:rotating_logger:Log message 572
# DEBUG:rotating_logger:Log message 573
# DEBUG:rotating_logger:Log message 574
# DEBUG:rotating_logger:Log message 575
# DEBUG:rotating_logger:Log message 576
# DEBUG:rotating_logger:Log message 577
# DEBUG:rotating_logger:Log message 578
# DEBUG:rotating_logger:Log message 579
# DEBUG:rotating_logger:Log message 580
# DEBUG:rotating_logger:Log message 581
# DEBUG:rotating_logger:Log message 582
# DEBUG:rotating_logger:Log message 583
# DEBUG:rotating_logger:Log message 584
# DEBUG:rotating_logger:Log message 585
# DEBUG:rotating_logger:Log message 586
# DEBUG:rotating_logger:Log message 587
# DEBUG:rotating_logger:Log message 588
# DEBUG:rotating_logger:Log message 589
# DEBUG:rotating_logger:Log message 590
# DEBUG:rotating_logger:Log message 591
# DEBUG:rotating_logger:Log message 592
# DEBUG:rotating_logger:Log message 593
# DEBUG:rotating_logger:Log message 594
# DEBUG:rotating_logger:Log message 595
# DEBUG:rotating_logger:Log message 596
# DEBUG:rotating_logger:Log message 597
# DEBUG:rotating_logger:Log message 598
# DEBUG:rotating_logger:Log message 599
# DEBUG:rotating_logger:Log message 600
# DEBUG:rotating_logger:Log message 601
# DEBUG:rotating_logger:Log message 602
# DEBUG:rotating_logger:Log message 603
# DEBUG:rotating_logger:Log message 604
# DEBUG:rotating_logger:Log message 605
# DEBUG:rotating_logger:Log message 606
# DEBUG:rotating_logger:Log message 607
# DEBUG:rotating_logger:Log message 608
# DEBUG:rotating_logger:Log message 609
# DEBUG:rotating_logger:Log message 610
# DEBUG:rotating_logger:Log message 611
# DEBUG:rotating_logger:Log message 612
# DEBUG:rotating_logger:Log message 613
# DEBUG:rotating_logger:Log message 614
# DEBUG:rotating_logger:Log message 615
# DEBUG:rotating_logger:Log message 616
# DEBUG:rotating_logger:Log message 617
# DEBUG:rotating_logger:Log message 618
# DEBUG:rotating_logger:Log message 619
# DEBUG:rotating_logger:Log message 620
# DEBUG:rotating_logger:Log message 621
# DEBUG:rotating_logger:Log message 622
# DEBUG:rotating_logger:Log message 623
# DEBUG:rotating_logger:Log message 624
# DEBUG:rotating_logger:Log message 625
# DEBUG:rotating_logger:Log message 626
# DEBUG:rotating_logger:Log message 627
# DEBUG:rotating_logger:Log message 628
# DEBUG:rotating_logger:Log message 629
# DEBUG:rotating_logger:Log message 630
# DEBUG:rotating_logger:Log message 631
# DEBUG:rotating_logger:Log message 632
# DEBUG:rotating_logger:Log message 633
# DEBUG:rotating_logger:Log message 634
# DEBUG:rotating_logger:Log message 635
# DEBUG:rotating_logger:Log message 636
# DEBUG:rotating_logger:Log message 637
# DEBUG:rotating_logger:Log message 638
# DEBUG:rotating_logger:Log message 639
# DEBUG:rotating_logger:Log message 640
# DEBUG:rotating_logger:Log message 641
# DEBUG:rotating_logger:Log message 642
# DEBUG:rotating_logger:Log message 643
# DEBUG:rotating_logger:Log message 644
# DEBUG:rotating_logger:Log message 645
# DEBUG:rotating_logger:Log message 646
# DEBUG:rotating_logger:Log message 647
# DEBUG:rotating_logger:Log message 648
# DEBUG:rotating_logger:Log message 649
# DEBUG:rotating_logger:Log message 650
# DEBUG:rotating_logger:Log message 651
# DEBUG:rotating_logger:Log message 652
# DEBUG:rotating_logger:Log message 653
# DEBUG:rotating_logger:Log message 654
# DEBUG:rotating_logger:Log message 655
# DEBUG:rotating_logger:Log message 656
# DEBUG:rotating_logger:Log message 657
# DEBUG:rotating_logger:Log message 658
# DEBUG:rotating_logger:Log message 659
# DEBUG:rotating_logger:Log message 660
# DEBUG:rotating_logger:Log message 661
# DEBUG:rotating_logger:Log message 662
# DEBUG:rotating_logger:Log message 663
# DEBUG:rotating_logger:Log message 664
# DEBUG:rotating_logger:Log message 665
# DEBUG:rotating_logger:Log message 666
# DEBUG:rotating_logger:Log message 667
# DEBUG:rotating_logger:Log message 668
# DEBUG:rotating_logger:Log message 669
# DEBUG:rotating_logger:Log message 670
# DEBUG:rotating_logger:Log message 671
# DEBUG:rotating_logger:Log message 672
# DEBUG:rotating_logger:Log message 673
# DEBUG:rotating_logger:Log message 674
# DEBUG:rotating_logger:Log message 675
# DEBUG:rotating_logger:Log message 676
# DEBUG:rotating_logger:Log message 677
# DEBUG:rotating_logger:Log message 678
# DEBUG:rotating_logger:Log message 679
# DEBUG:rotating_logger:Log message 680
# DEBUG:rotating_logger:Log message 681
# DEBUG:rotating_logger:Log message 682
# DEBUG:rotating_logger:Log message 683
# DEBUG:rotating_logger:Log message 684
# DEBUG:rotating_logger:Log message 685
# DEBUG:rotating_logger:Log message 686
# DEBUG:rotating_logger:Log message 687
# DEBUG:rotating_logger:Log message 688
# DEBUG:rotating_logger:Log message 689
# DEBUG:rotating_logger:Log message 690
# DEBUG:rotating_logger:Log message 691
# DEBUG:rotating_logger:Log message 692
# DEBUG:rotating_logger:Log message 693
# DEBUG:rotating_logger:Log message 694
# DEBUG:rotating_logger:Log message 695
# DEBUG:rotating_logger:Log message 696
# DEBUG:rotating_logger:Log message 697
# DEBUG:rotating_logger:Log message 698
# DEBUG:rotating_logger:Log message 699
# DEBUG:rotating_logger:Log message 700
# DEBUG:rotating_logger:Log message 701
# DEBUG:rotating_logger:Log message 702
# DEBUG:rotating_logger:Log message 703
# DEBUG:rotating_logger:Log message 704
# DEBUG:rotating_logger:Log message 705
# DEBUG:rotating_logger:Log message 706
# DEBUG:rotating_logger:Log message 707
# DEBUG:rotating_logger:Log message 708
# DEBUG:rotating_logger:Log message 709
# DEBUG:rotating_logger:Log message 710
# DEBUG:rotating_logger:Log message 711
# DEBUG:rotating_logger:Log message 712
# DEBUG:rotating_logger:Log message 713
# DEBUG:rotating_logger:Log message 714
# DEBUG:rotating_logger:Log message 715
# DEBUG:rotating_logger:Log message 716
# DEBUG:rotating_logger:Log message 717
# DEBUG:rotating_logger:Log message 718
# DEBUG:rotating_logger:Log message 719
# DEBUG:rotating_logger:Log message 720
# DEBUG:rotating_logger:Log message 721
# DEBUG:rotating_logger:Log message 722
# DEBUG:rotating_logger:Log message 723
# DEBUG:rotating_logger:Log message 724
# DEBUG:rotating_logger:Log message 725
# DEBUG:rotating_logger:Log message 726
# DEBUG:rotating_logger:Log message 727
# DEBUG:rotating_logger:Log message 728
# DEBUG:rotating_logger:Log message 729
# DEBUG:rotating_logger:Log message 730
# DEBUG:rotating_logger:Log message 731
# DEBUG:rotating_logger:Log message 732
# DEBUG:rotating_logger:Log message 733
# DEBUG:rotating_logger:Log message 734
# DEBUG:rotating_logger:Log message 735
# DEBUG:rotating_logger:Log message 736
# DEBUG:rotating_logger:Log message 737
# DEBUG:rotating_logger:Log message 738
# DEBUG:rotating_logger:Log message 739
# DEBUG:rotating_logger:Log message 740
# DEBUG:rotating_logger:Log message 741
# DEBUG:rotating_logger:Log message 742
# DEBUG:rotating_logger:Log message 743
# DEBUG:rotating_logger:Log message 744
# DEBUG:rotating_logger:Log message 745
# DEBUG:rotating_logger:Log message 746
# DEBUG:rotating_logger:Log message 747
# DEBUG:rotating_logger:Log message 748
# DEBUG:rotating_logger:Log message 749
# DEBUG:rotating_logger:Log message 750
# DEBUG:rotating_logger:Log message 751
# DEBUG:rotating_logger:Log message 752
# DEBUG:rotating_logger:Log message 753
# DEBUG:rotating_logger:Log message 754
# DEBUG:rotating_logger:Log message 755
# DEBUG:rotating_logger:Log message 756
# DEBUG:rotating_logger:Log message 757
# DEBUG:rotating_logger:Log message 758
# DEBUG:rotating_logger:Log message 759
# DEBUG:rotating_logger:Log message 760
# DEBUG:rotating_logger:Log message 761
# DEBUG:rotating_logger:Log message 762
# DEBUG:rotating_logger:Log message 763
# DEBUG:rotating_logger:Log message 764
# DEBUG:rotating_logger:Log message 765
# DEBUG:rotating_logger:Log message 766
# DEBUG:rotating_logger:Log message 767
# DEBUG:rotating_logger:Log message 768
# DEBUG:rotating_logger:Log message 769
# DEBUG:rotating_logger:Log message 770
# DEBUG:rotating_logger:Log message 771
# DEBUG:rotating_logger:Log message 772
# DEBUG:rotating_logger:Log message 773
# DEBUG:rotating_logger:Log message 774
# DEBUG:rotating_logger:Log message 775
# DEBUG:rotating_logger:Log message 776
# DEBUG:rotating_logger:Log message 777
# DEBUG:rotating_logger:Log message 778
# DEBUG:rotating_logger:Log message 779
# DEBUG:rotating_logger:Log message 780
# DEBUG:rotating_logger:Log message 781
# DEBUG:rotating_logger:Log message 782
# DEBUG:rotating_logger:Log message 783
# DEBUG:rotating_logger:Log message 784
# DEBUG:rotating_logger:Log message 785
# DEBUG:rotating_logger:Log message 786
# DEBUG:rotating_logger:Log message 787
# DEBUG:rotating_logger:Log message 788
# DEBUG:rotating_logger:Log message 789
# DEBUG:rotating_logger:Log message 790
# DEBUG:rotating_logger:Log message 791
# DEBUG:rotating_logger:Log message 792
# DEBUG:rotating_logger:Log message 793
# DEBUG:rotating_logger:Log message 794
# DEBUG:rotating_logger:Log message 795
# DEBUG:rotating_logger:Log message 796
# DEBUG:rotating_logger:Log message 797
# DEBUG:rotating_logger:Log message 798
# DEBUG:rotating_logger:Log message 799
# DEBUG:rotating_logger:Log message 800
# DEBUG:rotating_logger:Log message 801
# DEBUG:rotating_logger:Log message 802
# DEBUG:rotating_logger:Log message 803
# DEBUG:rotating_logger:Log message 804
# DEBUG:rotating_logger:Log message 805
# DEBUG:rotating_logger:Log message 806
# DEBUG:rotating_logger:Log message 807
# DEBUG:rotating_logger:Log message 808
# DEBUG:rotating_logger:Log message 809
# DEBUG:rotating_logger:Log message 810
# DEBUG:rotating_logger:Log message 811
# DEBUG:rotating_logger:Log message 812
# DEBUG:rotating_logger:Log message 813
# DEBUG:rotating_logger:Log message 814
# DEBUG:rotating_logger:Log message 815
# DEBUG:rotating_logger:Log message 816
# DEBUG:rotating_logger:Log message 817
# DEBUG:rotating_logger:Log message 818
# DEBUG:rotating_logger:Log message 819
# DEBUG:rotating_logger:Log message 820
# DEBUG:rotating_logger:Log message 821
# DEBUG:rotating_logger:Log message 822
# DEBUG:rotating_logger:Log message 823
# DEBUG:rotating_logger:Log message 824
# DEBUG:rotating_logger:Log message 825
# DEBUG:rotating_logger:Log message 826
# DEBUG:rotating_logger:Log message 827
# DEBUG:rotating_logger:Log message 828
# DEBUG:rotating_logger:Log message 829
# DEBUG:rotating_logger:Log message 830
# DEBUG:rotating_logger:Log message 831
# DEBUG:rotating_logger:Log message 832
# DEBUG:rotating_logger:Log message 833
# DEBUG:rotating_logger:Log message 834
# DEBUG:rotating_logger:Log message 835
# DEBUG:rotating_logger:Log message 836
# DEBUG:rotating_logger:Log message 837
# DEBUG:rotating_logger:Log message 838
# DEBUG:rotating_logger:Log message 839
# DEBUG:rotating_logger:Log message 840
# DEBUG:rotating_logger:Log message 841
# DEBUG:rotating_logger:Log message 842
# DEBUG:rotating_logger:Log message 843
# DEBUG:rotating_logger:Log message 844
# DEBUG:rotating_logger:Log message 845
# DEBUG:rotating_logger:Log message 846
# DEBUG:rotating_logger:Log message 847
# DEBUG:rotating_logger:Log message 848
# DEBUG:rotating_logger:Log message 849
# DEBUG:rotating_logger:Log message 850
# DEBUG:rotating_logger:Log message 851
# DEBUG:rotating_logger:Log message 852
# DEBUG:rotating_logger:Log message 853
# DEBUG:rotating_logger:Log message 854
# DEBUG:rotating_logger:Log message 855
# DEBUG:rotating_logger:Log message 856
# DEBUG:rotating_logger:Log message 857
# DEBUG:rotating_logger:Log message 858
# DEBUG:rotating_logger:Log message 859
# DEBUG:rotating_logger:Log message 860
# DEBUG:rotating_logger:Log message 861
# DEBUG:rotating_logger:Log message 862
# DEBUG:rotating_logger:Log message 863
# DEBUG:rotating_logger:Log message 864
# DEBUG:rotating_logger:Log message 865
# DEBUG:rotating_logger:Log message 866
# DEBUG:rotating_logger:Log message 867
# DEBUG:rotating_logger:Log message 868
# DEBUG:rotating_logger:Log message 869
# DEBUG:rotating_logger:Log message 870
# DEBUG:rotating_logger:Log message 871
# DEBUG:rotating_logger:Log message 872
# DEBUG:rotating_logger:Log message 873
# DEBUG:rotating_logger:Log message 874
# DEBUG:rotating_logger:Log message 875
# DEBUG:rotating_logger:Log message 876
# DEBUG:rotating_logger:Log message 877
# DEBUG:rotating_logger:Log message 878
# DEBUG:rotating_logger:Log message 879
# DEBUG:rotating_logger:Log message 880
# DEBUG:rotating_logger:Log message 881
# DEBUG:rotating_logger:Log message 882
# DEBUG:rotating_logger:Log message 883
# DEBUG:rotating_logger:Log message 884
# DEBUG:rotating_logger:Log message 885
# DEBUG:rotating_logger:Log message 886
# DEBUG:rotating_logger:Log message 887
# DEBUG:rotating_logger:Log message 888
# DEBUG:rotating_logger:Log message 889
# DEBUG:rotating_logger:Log message 890
# DEBUG:rotating_logger:Log message 891
# DEBUG:rotating_logger:Log message 892
# DEBUG:rotating_logger:Log message 893
# DEBUG:rotating_logger:Log message 894
# DEBUG:rotating_logger:Log message 895
# DEBUG:rotating_logger:Log message 896
# DEBUG:rotating_logger:Log message 897
# DEBUG:rotating_logger:Log message 898
# DEBUG:rotating_logger:Log message 899
# DEBUG:rotating_logger:Log message 900
# DEBUG:rotating_logger:Log message 901
# DEBUG:rotating_logger:Log message 902
# DEBUG:rotating_logger:Log message 903
# DEBUG:rotating_logger:Log message 904
# DEBUG:rotating_logger:Log message 905
# DEBUG:rotating_logger:Log message 906
# DEBUG:rotating_logger:Log message 907
# DEBUG:rotating_logger:Log message 908
# DEBUG:rotating_logger:Log message 909
# DEBUG:rotating_logger:Log message 910
# DEBUG:rotating_logger:Log message 911
# DEBUG:rotating_logger:Log message 912
# DEBUG:rotating_logger:Log message 913
# DEBUG:rotating_logger:Log message 914
# DEBUG:rotating_logger:Log message 915
# DEBUG:rotating_logger:Log message 916
# DEBUG:rotating_logger:Log message 917
# DEBUG:rotating_logger:Log message 918
# DEBUG:rotating_logger:Log message 919
# DEBUG:rotating_logger:Log message 920
# DEBUG:rotating_logger:Log message 921
# DEBUG:rotating_logger:Log message 922
# DEBUG:rotating_logger:Log message 923
# DEBUG:rotating_logger:Log message 924
# DEBUG:rotating_logger:Log message 925
# DEBUG:rotating_logger:Log message 926
# DEBUG:rotating_logger:Log message 927
# DEBUG:rotating_logger:Log message 928
# DEBUG:rotating_logger:Log message 929
# DEBUG:rotating_logger:Log message 930
# DEBUG:rotating_logger:Log message 931
# DEBUG:rotating_logger:Log message 932
# DEBUG:rotating_logger:Log message 933
# DEBUG:rotating_logger:Log message 934
# DEBUG:rotating_logger:Log message 935
# DEBUG:rotating_logger:Log message 936
# DEBUG:rotating_logger:Log message 937
# DEBUG:rotating_logger:Log message 938
# DEBUG:rotating_logger:Log message 939
# DEBUG:rotating_logger:Log message 940
# DEBUG:rotating_logger:Log message 941
# DEBUG:rotating_logger:Log message 942
# DEBUG:rotating_logger:Log message 943
# DEBUG:rotating_logger:Log message 944
# DEBUG:rotating_logger:Log message 945
# DEBUG:rotating_logger:Log message 946
# DEBUG:rotating_logger:Log message 947
# DEBUG:rotating_logger:Log message 948
# DEBUG:rotating_logger:Log message 949
# DEBUG:rotating_logger:Log message 950
# DEBUG:rotating_logger:Log message 951
# DEBUG:rotating_logger:Log message 952
# DEBUG:rotating_logger:Log message 953
# DEBUG:rotating_logger:Log message 954
# DEBUG:rotating_logger:Log message 955
# DEBUG:rotating_logger:Log message 956
# DEBUG:rotating_logger:Log message 957
# DEBUG:rotating_logger:Log message 958
# DEBUG:rotating_logger:Log message 959
# DEBUG:rotating_logger:Log message 960
# DEBUG:rotating_logger:Log message 961
# DEBUG:rotating_logger:Log message 962
# DEBUG:rotating_logger:Log message 963
# DEBUG:rotating_logger:Log message 964
# DEBUG:rotating_logger:Log message 965
# DEBUG:rotating_logger:Log message 966
# DEBUG:rotating_logger:Log message 967
# DEBUG:rotating_logger:Log message 968
# DEBUG:rotating_logger:Log message 969
# DEBUG:rotating_logger:Log message 970
# DEBUG:rotating_logger:Log message 971
# DEBUG:rotating_logger:Log message 972
# DEBUG:rotating_logger:Log message 973
# DEBUG:rotating_logger:Log message 974
# DEBUG:rotating_logger:Log message 975
# DEBUG:rotating_logger:Log message 976
# DEBUG:rotating_logger:Log message 977
# DEBUG:rotating_logger:Log message 978
# DEBUG:rotating_logger:Log message 979
# DEBUG:rotating_logger:Log message 980
# DEBUG:rotating_logger:Log message 981
# DEBUG:rotating_logger:Log message 982
# DEBUG:rotating_logger:Log message 983
# DEBUG:rotating_logger:Log message 984
# DEBUG:rotating_logger:Log message 985
# DEBUG:rotating_logger:Log message 986
# DEBUG:rotating_logger:Log message 987
# DEBUG:rotating_logger:Log message 988
# DEBUG:rotating_logger:Log message 989
# DEBUG:rotating_logger:Log message 990
# DEBUG:rotating_logger:Log message 991
# DEBUG:rotating_logger:Log message 992
# DEBUG:rotating_logger:Log message 993
# DEBUG:rotating_logger:Log message 994
# DEBUG:rotating_logger:Log message 995
# DEBUG:rotating_logger:Log message 996
# DEBUG:rotating_logger:Log message 997
# DEBUG:rotating_logger:Log message 998
# DEBUG:rotating_logger:Log message 999
